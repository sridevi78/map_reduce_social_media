# %% [markdown]
# Simple social network task. Consider a simple social network dataset, where key = person and value = some friend of that person. Describe a MapReduce algorithm to count he number of friends each person has. Data was collected from here: http://snap.stanford.edu/data/egonets-Facebook.html

# %%
# %matplotlib inline
import matplotlib
import seaborn as sns
matplotlib.rcParams['savefig.dpi'] = 144

# %%
# %%writefile my_mr.py
from mrjob.job import MRJob
import heapq as hp
import re

class FirstStep(MRJob):
    def mapper(self,_,line):
        lis=line.split(' ')
        for num in lis:
            yield (int(num),1)
    def reducer(self,word,values):
        yield ('red',(sum(values),word))
            
class SecondStep(MRJob):
    def reducer(self,key,records):
        self.heap1=[] 
        for item in records:
            hp.heappush(self.heap1,(int(item[0]),int(item[1])))
        #print hp.nlargest(100,self.heap1)
        #yield ('key',(hp.nlargest(100,self.heap1)))
        yield ('key',self.heap1)

class ThirdStep(MRJob):
    def reducer(self,key,items):
        self.com_heap=[]
        for item in items:
            hp.heappush(self.com_heap,item)
        yield ('key2',self.com_heap)
    
class SteppedJob(MRJob):
    def steps(self):
        return FirstStep().steps()+SecondStep().steps()+ThirdStep().steps()
   
if __name__ == '__main__':
    SteppedJob.run()
# Out:
# Overwriting my_mr.py

# %%
# !python my_mr.py -r inline 'facebook/*.edges' > out1.txt
# Out:
# No configs found; falling back on auto-configuration
# No configs specified for inline runner
# Running step 1 of 3...
# Creating temp directory /var/folders/vh/j55dyd2x3sz4gybmf6v7g9380000gn/T/my_mr.home.20180110.184711.346196
# Running step 2 of 3...
# Running step 3 of 3...
# Streaming final output from /var/folders/vh/j55dyd2x3sz4gybmf6v7g9380000gn/T/my_mr.home.20180110.184711.346196/output...
# Removing temp directory /var/folders/vh/j55dyd2x3sz4gybmf6v7g9380000gn/T/my_mr.home.20180110.184711.346196...

# %%
import re
with open('out1.txt','r') as f:
    fout=f.read()
f.close()
#print fout
values=fout.split('\t')
ls=values[1].split(',')
tup=[]
sum_=0
for i in range(0,len(ls),2):
    cnt= ls[i].replace('[','')
    word1= ls[i+1].replace('"','')
    word=word1.replace(']','')
    tup.append((int(word),int(cnt)))
    sum_+=int(cnt)

# %% [markdown]
# each tuple has two entries, one for the node number and the other for the number of connections

# %%
print sum_
print len(tup)
print "**************"
print tup
# Out:
# 340348
# 3959
# **************
# [(33, 2), (35, 2), (70, 2), (145, 2), (42, 2), (90, 2), (138, 2), (234, 2), (183, 2), (256, 2), (47, 2), (154, 2), (153, 2), (282, 2), (216, 2), (267, 2), (286, 2), (241, 2), (244, 2), (377, 2), (1967, 2), (255, 2), (52, 2), (160, 2), (205, 2), (841, 2), (2788, 2), (1065, 2), (1176, 2), (305, 2), (2814, 2), (3268, 2), (336, 4), (3407, 2), (179, 4), (1854, 2), (2382, 2), (288, 6), (3688, 2), (379, 2), (3807, 2), (3854, 2), (2541, 2), (1430, 2), (401, 2), (468, 2), (233, 2), (581, 2), (279, 2), (744, 2), (775, 2), (1690, 2), (859, 2), (97, 4), (0, 4), (1755, 2), (112, 4), (1224, 2), (1233, 2), (1326, 2), (316, 2), (321, 4), (2691, 4), (228, 4), (3282, 2), (1776, 8), (3375, 4), (340, 10), (3408, 2), (182, 4), (3494, 6), (2740, 2), (2380, 4), (356, 4), (2857, 2), (3619, 6), (3653, 6), (247, 4), (3704, 2), (2483, 4), (3746, 2), (3808, 2), (3846, 2), (3875, 2), (3885, 2), (3922, 2), (3942, 2), (3987, 2), (3983, 2), (4034, 2), (443, 2), (2922, 4), (499, 4), (530, 6), (571, 4), (2704, 2), (61, 4), (648, 2), (642, 2), (294, 4), (749, 2), (76, 4), (81, 4), (207, 4), (164, 4), (899, 4), (910, 8), (2792, 4), (1693, 4), (174, 6), (1027, 4), (301, 4), (1760, 4), (2798, 4), (2998, 4), (120, 6), (3006, 2), (3125, 2), (1262, 2), (1295, 8), (3037, 4), (1362, 4), (1394, 2), (27, 8), (2219, 8), (2808, 4), (3251, 16), (1777, 8), (327, 6), (3305, 8), (3310, 8), (3323, 12), (1792, 10), (1797, 8), (2838, 6), (3389, 12), (338, 12), (3413, 4), (3429, 8), (3444, 8), (3467, 4), (3477, 10), (235, 8), (2855, 6), (3513, 10), (3537, 6), (2714, 4), (2860, 4), (3575, 4), (3589, 2), (240, 4), (1865, 14), (3637, 8), (2422, 8), (2431, 8), (3673, 6), (3689, 4), (2442, 4), (3732, 2), (3733, 4), (289, 6), (3765, 6), (2481, 4), (2505, 8), (3801, 4), (2527, 6), (383, 4), (386, 4), (3879, 2), (293, 4), (3897, 6), (2565, 6), (3928, 4), (3946, 6), (3959, 2), (1417, 8), (3991, 4), (4001, 2), (4028, 2), (191, 4), (4036, 2), (2595, 4), (448, 4), (467, 6), (485, 8), (49, 6), (51, 12), (1510, 6), (533, 10), (1996, 6), (552, 6), (152, 8), (593, 8), (2952, 4), (201, 6), (1558, 2), (656, 4), (673, 6), (699, 2), (704, 8), (717, 6), (743, 4), (750, 2), (1607, 8), (785, 4), (790, 6), (206, 6), (83, 12), (2975, 4), (854, 4), (865, 6), (893, 6), (904, 4), (91, 14), (929, 8), (945, 6), (1701, 12), (1713, 6), (996, 6), (1002, 6), (1022, 6), (1034, 4), (1046, 4), (1057, 8), (1071, 4), (1762, 6), (1105, 6), (307, 6), (3003, 6), (1147, 8), (117, 10), (3094, 12), (1194, 6), (311, 12), (1208, 4), (2168, 4), (1252, 4), (1270, 2), (1276, 2), (2692, 8), (3147, 8), (219, 10), (1346, 8), (270, 6), (220, 6), (1383, 6), (1395, 2), (221, 14), (3217, 10), (2817, 8), (3227, 8), (2227, 12), (2230, 8), (177, 20), (2238, 24), (2621, 10), (3271, 8), (260, 14), (3290, 8), (2826, 18), (2256, 12), (2263, 12), (3317, 12), (3322, 14), (3333, 12), (3336, 12), (2824, 10), (3354, 16), (229, 10), (337, 16), (3370, 10), (2301, 18), (230, 16), (34, 14), (2321, 12), (2651, 12), (3418, 18), (3424, 12), (3432, 10), (3441, 10), (3447, 10), (3457, 10), (283, 8), (3472, 28), (347, 12), (3489, 8), (349, 8), (2358, 10), (351, 8), (3515, 20), (3522, 16), (237, 12), (2375, 10), (3544, 8), (1838, 10), (3560, 4), (3565, 6), (2725, 14), (3582, 4), (2722, 4), (3597, 4), (3606, 8), (1856, 6), (3614, 18), (3626, 14), (2421, 14), (3632, 10), (243, 14), (365, 10), (3660, 10), (2437, 8), (3676, 8), (3686, 6), (3691, 4), (3699, 4), (371, 8), (3717, 4), (2456, 14), (3724, 10), (189, 12), (3744, 4), (3749, 10), (1890, 10), (250, 8), (3771, 12), (2736, 8), (3781, 6), (263, 12), (3795, 8), (3811, 4), (3816, 4), (2893, 14), (2517, 10), (2885, 6), (384, 6), (1937, 6), (3865, 6), (3871, 14), (253, 4), (3882, 6), (3890, 8), (390, 10), (3904, 12), (192, 8), (3910, 6), (3925, 8), (3939, 6), (2580, 10), (3952, 6), (3955, 4), (3965, 6), (259, 14), (3970, 10), (3992, 4), (3996, 6), (4005, 4), (4006, 2), (4018, 12), (4029, 2), (4033, 4), (411, 4), (2632, 12), (427, 26), (429, 18), (44, 10), (1442, 8), (454, 4), (1461, 14), (1474, 6), (478, 14), (47 ...

# %% [markdown]
# Now lets get the top 100 nodes with the most connections

# %%
# %%writefile my_mr1.py
from mrjob.job import MRJob
import heapq as hp
import re

class FirstStep(MRJob):
    def mapper(self,_,line):
        lis=line.split(' ')
        for num in lis:
            yield (int(num),1)
    def reducer(self,word,values):
        yield ('red',(sum(values),word))
            
class SecondStep(MRJob):
    def reducer(self,key,records):
        self.heap1=[] 
        for item in records:
            hp.heappush(self.heap1,(int(item[0]),int(item[1])))
        #print hp.nlargest(100,self.heap1)
        yield ('key',(hp.nlargest(100,self.heap1)))
        #yield ('key',self.heap1)
        
class ThirdStep(MRJob):
    def reducer(self,key,items):
        self.com_heap=[]
        for item in items:
            hp.heappush(self.com_heap,item)
        yield ('key2',hp.nlargest(100,self.com_heap))        

class SteppedJob(MRJob):
    def steps(self):
        return FirstStep().steps()+SecondStep().steps()+ThirdStep().steps()

if __name__ == '__main__':
    SteppedJob.run()
# Out:
# Overwriting my_mr1.py

# %%
# !python my_mr1.py -r inline 'facebook/*.edges' > out2.txt
# Out:
# No configs found; falling back on auto-configuration
# No configs specified for inline runner
# Running step 1 of 3...
# Creating temp directory /var/folders/vh/j55dyd2x3sz4gybmf6v7g9380000gn/T/my_mr1.home.20180110.184803.451576
# Running step 2 of 3...
# Running step 3 of 3...
# Streaming final output from /var/folders/vh/j55dyd2x3sz4gybmf6v7g9380000gn/T/my_mr1.home.20180110.184803.451576/output...
# Removing temp directory /var/folders/vh/j55dyd2x3sz4gybmf6v7g9380000gn/T/my_mr1.home.20180110.184803.451576...

# %%
import re
with open('out2.txt','r') as f:
    fout=f.read()
f.close()
#print fout
values=fout.split('\t')
ls=values[1].split(',')
tup=[]
sum_=0
for i in range(0,len(ls),2):
    cnt= ls[i].replace('[','')
    word1= ls[i+1].replace('"','')
    word=word1.replace(']','')
    tup.append((int(word),int(cnt)))
    sum_+=int(cnt)

# %%
print sum_
print len(tup)
print "**************"
print tup
# Out:
# 39878
# 100
# **************
# [(2543, 586), (2347, 580), (483, 568), (1888, 506), (1800, 488), (1663, 468), (2266, 466), (1352, 466), (1730, 450), (1985, 446), (1941, 444), (2233, 442), (2142, 440), (1431, 438), (1199, 432), (1584, 420), (2206, 418), (1768, 416), (2611, 412), (2410, 412), (2229, 412), (2218, 408), (2047, 408), (1589, 408), (1086, 408), (2078, 406), (2123, 404), (1993, 404), (2464, 402), (1746, 402), (2560, 400), (2507, 400), (2240, 400), (1827, 400), (2244, 398), (2309, 396), (1983, 396), (2602, 394), (2340, 394), (2131, 394), (2088, 394), (1126, 394), (2590, 392), (2369, 392), (2324, 392), (2604, 390), (2542, 390), (2607, 388), (2220, 388), (2073, 388), (1804, 388), (2188, 386), (2172, 384), (2059, 384), (1390, 384), (2150, 382), (1943, 382), (2526, 380), (2428, 380), (1946, 380), (1833, 380), (2601, 378), (2331, 378), (2201, 378), (1917, 378), (1612, 378), (1377, 378), (2090, 376), (1938, 376), (1621, 376), (376, 376), (2624, 374), (2564, 374), (2384, 374), (2118, 374), (2586, 372), (2030, 372), (1962, 372), (1714, 372), (2625, 370), (2184, 370), (2064, 370), (1559, 370), (2615, 368), (2593, 368), (2275, 368), (1707, 368), (2290, 366), (2111, 366), (2103, 366), (2414, 364), (2323, 364), (1078, 364), (2600, 362), (2339, 362), (1835, 362), (1613, 362), (1376, 362), (2500, 360), (2104, 360)]
